# %% [markdown]
# <a href="https://colab.research.google.com/github/davidofitaly/algebra_stats_probability_ds_notes/blob/main/01_basic_math_differential_integral_calculus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sympy import *
from matplotlib import style
from sympy.plotting import plot3d
import math


style.use('seaborn-v0_8')

# %% [markdown]
# ###*Order of operations*

# %% [markdown]
# ####excercise 1.1
#
# #####Calculate the value of the following expression:
#
# $$(10 + 5) \div 3^2 \times 4 - 6$$

# %%
my_value = (10 + 5) / 3**2 * 4 - 6

print(my_value)
# Out:
# 0.666666666666667

# %% [markdown]
# ####excercise 1.2
#
# #####Calculate the value of the following expression:
#
# $$((2 \times 7) - 5) \times \sqrt{4} \div \dfrac{15}{3} \times 9 - 5$$

# %%
my_value = ((2 * 7) - 5) * (4**0.5) / (15/3) * 9 -5

print(my_value)
# Out:
# 27.4

# %% [markdown]
# ####excercise 1.3
#
# #####Calculate the value of the following expression:
#
# $$
# \left( \frac{(5 \times 3 + 7)}{2} \right)^2 - \sqrt{81} \times \left( \frac{25}{5} + 3 \right) \div 4
# $$

# %%
my_value = ((5 * 3 + 7) / 2)**2  - (81 **0.5) * (25/5 + 3) / 4

print(my_value)
# Out:
# 103.0

# %% [markdown]
# ###*Variables*

# %% [markdown]
# ####excercise 1.4
#
# #####Write a program that asks the user to enter as integer and then calculcates and displays the product of the number by 3.

# %%
number = int(input('Enter a number: '))
product = number * 3

print(product)
# Out:
# Enter a number: 10
# 30

# %% [markdown]
# ####excercise 1.5
#
# #####Calculate the result of the equation:
#
# $$
# y = \beta \times \theta
# $$
#
# where:
# - $\beta = 1.75$
# - $\theta = 30.0$

# %%
beta = 1.75
theta = 30.0
y = beta * theta

print(y)
# Out:
# 52.5

# %% [markdown]
# ###*Functions*

# %%
def f(x):
    return 4 * x + 3

x_values = [0, 1, 2, 3, 4, 5, 6]

for x in x_values:
    y = f(x)
    print(y)
# Out:
# 3
# 7
# 11
# 15
# 19
# 23
# 27

# %% [markdown]
# ####excercise 1.6
#
# #####Calculate the values of a linear function
# $$
# f(x) = 4x + 3
# $$
#
# For $x$ from the list
#
# $$
# x = [0, 1, 2, 3, 4, 5, 6]
# $$

# %%
def f(x):
    return 4 * x + 3

x_values = [0, 1, 2, 3, 4, 5, 6]

for x in x_values:
    y = f(x)
    print(y)
# Out:
# 3
# 7
# 11
# 15
# 19
# 23
# 27

# %% [markdown]
# ####excercise 1.7
#
# #####Draw the graph of linear function:
#
# $$ f(x) = \dfrac{1}{3}x + 4 $$

# %%
x = symbols('x')
f = 1/3 * x + 4


plot(f)

# %% [markdown]
# ####excercise 1.8
#
# #####Draw the graph of quadratic function:
#
# $$ f(x) = 3x^2 - 2 $$

# %%
x = symbols('x')
f = 3 * x**2 -2

plot(f)

# %% [markdown]
# ####excercise 1.9
#
# #####Draw the graph of the following function:
#
# $$ f(x) = x + 5y $$

# %%
x, y = symbols('x y')
f = x + 5 * y

plot3d(f)

# %% [markdown]
# ###*Summing*

# %% [markdown]
# ####In mathematics, summation means adding element within a given range.
#
#
# ####General syntax:
# $$
# \sum_{i=m}^{n} a_i
# $$
#
# ####Where:
# - *i:* the summation index (iterative variable),
# - *m*: the lower bound of summation,
# - *n*: the upper bound of summation,
# - *a_i*: the expression to be summed.
#
# ####Example:
#
# $$
# \sum_{i=1}^{5} i = 1 + 2 + 3 + 4 + 5 = 15
# $$

# %% [markdown]
# ####excercise 1.10
#
# #####Write a program to calculate the sum of the squares of integers from 1 to 10 using a generator expression.
#
# \
#
# The sum of squares from $ 1^2 \,to\ 10^2 $ can be calculated as:
#
# $$
# \sum_{i=1}^{10} i^2 = 1^2 + 2^2 + \dots + 10^2
# $$

# %%
suma = sum(i**2 for i in range(1,11))

print(suma)
# Out:
# 385

# %% [markdown]
# ####excercise 1.11
#
# #####Write a program that calculates the sum of three times each number in the list numbers using a generator expression.
#
# \
#
# #####The sum can be written as:
#
# $$
# \text{Sum} = 3 \times (1 + 2 + 4 + 6 + 8)
# $$

# %%
numbers = [1,2,4,6,8]
n = len(numbers)

suma = sum(3*numbers[x] for x in range(0,n))

print(suma)
# Out:
# 63

# %% [markdown]
# ####excercise 1.12
#
# #####Write a program using **SymPy** to compute the sum of $3i + 2$ for $i$ from 1 to $n$, where $n$ is a symbolic variable. Then, substitute $n = 4$ and calculate the value of the sum.

# %%
i, n = symbols('i n')
suma = Sum(3*i +1, (i, 1,n))

sum_to_4 = suma.subs(n, 4)

print(sum_to_4.doit())
# Out:
# 34

# %% [markdown]
# ###*Exponentiation*

# %% [markdown]
# ####excercise 1.13
#
# #####Calculate the expression:  $ \frac{x^2}{x^5} $

# %%
x = symbols('x')

expression = x**2 / x**5

print(expression)
# Out:
# x**(-3)

# %% [markdown]
# ####excercise 1.14
#
# #####Calculate the expression:  $ y^3 \times y^{\frac{2}{3}} $

# %%
y = symbols('y')
expression = y**3 * y**(2/3)

print(expression)
# Out:
# y**3.66666666666667

# %% [markdown]
# ###*Logarithms*

# %% [markdown]
# In mathematics, a logarithm is the inverse operation to exponentiation.
#
# The general form of a logarithmic function is:
#
# $$
# \log_b(x) = y \quad \text{if and only if} \quad b^y = x
# $$
#
# Where:
# - *b* is the base of the logarithm,
# - *x* is the argument,
# - *y* is the result of the logarithm.
#
# #### Important Properties of Logarithms:
#
# 1. **Logarithm with Base \( e \)** (Natural Logarithm):
#    $$ \ln(x) \quad \text{is the logarithm to the base} \, e. $$
#
# 2. **Logarithm with Base 10**:
#    $$ \log_{10}(x) \quad \text{is the logarithm to the base 10.} $$
#
# 3. **Logarithmic Identity for Base 1**:
#    $$ \log_1(x) \quad \text{is undefined for any \( x \neq 1 \).} $$
#
# 4. **Zero Exponent Rule**:
#    - $ x^0 = 1  $ for any $ x \neq 0 $.
#    - The logarithm of 1 in any base is always 0:
#      $$ \log_b(1) = 0 \quad \text{for any base} \, b. $$
#
# 5. **Inverse Property of Logarithms**:
#    - Logarithms are the inverse of exponentiation:
#      $$ \log_b(x) = y \quad \text{if and only if} \quad b^y = x. $$
#
# 6. **Product Rule**:
#    $$ \log_b(xy) = \log_b(x) + \log_b(y) $$
#
# 7. **Quotient Rule**:
#    $$ \log_b\left(\frac{x}{y}\right) = \log_b(x) - \log_b(y) $$
#
# 8. **Power Rule**:
#    $$ \log_b(x^n) = n \cdot \log_b(x) $$
#
# #### Example:
# If $ 10^3 = 1000 $, then:
# $$ \log_{10}(1000) = 3 $$
#
# Similarly, if $ e^1 = e $, then:
# $$ \ln(e) = 1 $$

# %% [markdown]
# ####excercise 1.15
#
# #####Calculate the expression:  $ \log_{10}(100) + \log_{10}(10) $

# %%
result = math.log10(100) + math.log10(10)

print(result)
# Out:
# 3.0

# %% [markdown]
# ####excercise 1.16
#
# #####Calculate the expression: $ \log_2(8) - \log_2(2) $

# %%
result = math.log(8, 2) - math.log(2,2)

print(result)
# Out:
# 2.0

# %% [markdown]
# ####excercise 1.17
#
# #####Calculate the expression: $ \log_5(25) + \log_5(5)

# %%
result = math.log(25,5) + math.log(5,5)

print(result)
# Out:
# 3.0

# %% [markdown]
# ###*Euler number*

# %% [markdown]
# #####In mathematics, Euler's number, denoted as $ e $, is an irrational constant approximately equal to:
#
# $$
# e \approx 2.71828
# $$
#
# #####It is the base of the natural logarithm, and it arises naturally in many areas of mathematics, particularly in calculus.
# \
# ##### Key Properties of $ e $:
#
# 1. **Limit Definition**:
#    Euler's number can be defined as the limit of the following expression:
#
#    $$
#    e = \lim_{n \to \infty} \left( 1 + \frac{1}{n} \right)^n
#    $$
#
# 2. **Exponential Function**:
#    The exponential function $ e^x $ is one of the most important functions in mathematics and is defined as:
#
#    $$
#    e^x = \lim_{n \to \infty} \left( 1 + \frac{x}{n} \right)^n
#    $$
#
#    It has the unique property that its derivative is equal to the function itself:
#
#    $$
#    \frac{d}{dx} e^x = e^x
#    $$
#
# 3. **Natural Logarithm**:
#    The natural logarithm $ \ln(x) $ is the logarithm to the base $ e $, and it is the inverse of the exponential function:
#
#    $$
#    \ln(x) = \log_e(x)
#    $$

# %% [markdown]
# ####excercise 1.18
# ##### Calculate the future value $FV$ of an investment:
#
# #####Given the following parameters:
# - Present value *PV* = 120
# - Interest rate *r* = 30% (0.20)
# - Time *t* = 3 years
#
# #####Use the compound interest formula:
#
# $$
# FV = PV \times \left(1 + \frac{r}{n}\right)^{n \times t}
# $$
#
# #####Where:
# - For monthly compounding, set $ n = 12 $.
# - For daily compounding, set $ n = 365 $.
# - For minute-by-minute compounding, set $ n = 525600 $
#
# #####Calculate the future value $FV$ for all three cases.

# %%
pv = 120
r = .30
t = 3.0
n = [12, 365, 525600]

results = ['Monthy', 'Daily', 'Minute by minute']
for i, value in enumerate(n):
    fv = pv * (1 + r/value)**(value*t)
    print(f"{results[i]} compounding: {fv}")
# Out:
# Monthy compounding: 291.90423788614714
# Daily compounding: 295.04328733626744
# Minute by minute compounding: 295.1522975790582

# %% [markdown]
# #### exercise 1.19
# ##### Calculate the future value $FV$ of an investment:
#
# #####Given the following parameters:
# - Present value *PV* = 200
# - Interest rate *r* = 40% (0.40)
# - Time *t* = 10 years
#
# #####Use the continuous compound interest formula:
#
# $$
# FV = PV \times e^{r \times t}
# $$
#
#
# #####Calculate the future value $FV$ for this investment.

# %%
pv = 200
r = 0.40
t = 10

fv = pv * exp(r*t)
print(fv)
# Out:
# 10919.6300066288

# %% [markdown]
# ###*Limits*

# %% [markdown]
# #####In calculus, a **limit** is a fundamental concept that describes the behavior of a function as its argument approaches a particular point.
#
# #####The limit of a function $ f(x) $ as $ x $ approaches a value $ c $ is written as:
#
# $$
# \lim_{x \to c} f(x) = L
# $$
#
# #####Where:
# - $ x $ is the independent variable,
# - $ c $ is the value that $ x $ approaches,
# - $ L $ is the value that $ f(x) $ approaches as $ x $ approaches $ c $.
#
# ##### Types of Limits:
# 1. **Finite Limits:**
#    $$ \lim_{x \to c} f(x) = L $$
#    This means that the function approaches a finite value $ L $ as $ x $ approaches $ c $.
#
# 2. **Infinite Limits:**
#    $$ \lim_{x \to c} f(x) = \infty $$
#    This occurs when the function grows without bound as $ x $ approaches $ c $.
#
# 3. **Limits at Infinity:**
#    $$ \lim_{x \to \infty} f(x) = L $$
#    This describes the behavior of a function as $ x $ grows larger and larger.
#
# ##### Important Limit Laws:
# - **Sum Law:**
#    $$ \lim_{x \to c} (f(x) + g(x)) = \lim_{x \to c} f(x) + \lim_{x \to c} g(x) $$
#
# - **Product Law:**
#    $$ \lim_{x \to c} (f(x) \cdot g(x)) = \lim_{x \to c} f(x) \cdot \lim_{x \to c} g(x) $$
#
# - **Quotient Law:**
#    $$ \lim_{x \to c} \left( \frac{f(x)}{g(x)} \right) = \frac{\lim_{x \to c} f(x)}{\lim_{x \to c} g(x)} $$
#
# - **Power Law:**
#    $$ \lim_{x \to c} f(x)^n = \left( \lim_{x \to c} f(x) \right)^n $$

# %%
#kod

# %% [markdown]
# ###*Derivatives*
#
# ##### In calculus, a **derivative** is a fundamental concept that describes the rate of change of a function at a particular point.
#
# ##### The derivative of a function $ f(x) $ at a point $ x = c $ is written as:
#
# $$
# f'(c) = \lim_{h \to 0} \frac{f(c+h) - f(c)}{h}
# $$
#
# ##### Where:
# - $ f'(c) $ is the derivative of $ f(x) $ at $ x = c $,
# - $ h $ is a small change in $ x $,
# - $ f(c+h) - f(c) $ is the change in the function's value,
# - The ratio $ \frac{f(c+h) - f(c)}{h} $ represents the slope of the secant line between two points on the curve, and as $ h $ approaches 0, this gives the slope of the tangent line at $ x = c $.
#
# ##### Types of Derivatives:
# 1. **First Derivative:**
#    The first derivative of a function $ f(x) $ represents the rate of change or slope of the function. It is denoted as $ f'(x) $ or $ \frac{d}{dx} f(x) $.
#
#    - Geometrically, it gives the slope of the tangent line to the curve at a point.
#
# 2. **Second Derivative:**
#    The second derivative of a function $ f(x) $ is the derivative of the first derivative, written as $ f''(x) $ or $ \frac{d^2}{dx^2} f(x) $.
#
#    - It measures the concavity of the function, or how the slope of the function is changing.
#
# ##### Common Rules for Derivatives:
# - **Constant Rule:**
#    If $ f(x) = c $ (where $ c $ is a constant), then:
#    $$
#    f'(x) = 0
#    $$
#
# - **Power Rule:**
#    If $ f(x) = x^n $ (where $ n $ is a constant), then:
#    $$
#    f'(x) = n x^{n-1}
#    $$
#
# - **Sum Rule:**
#    If $ f(x) = g(x) + h(x) $, then:
#    $$
#    f'(x) = g'(x) + h'(x)
#    $$
#
# - **Product Rule:**
#    If $ f(x) = g(x) \cdot h(x) $, then:
#    $$
#    f'(x) = g'(x) \cdot h(x) + g(x) \cdot h'(x)
#    $$
#
# - **Quotient Rule:**
#    If $ f(x) = \frac{g(x)}{h(x)} $, then:
#    $$
#    f'(x) = \frac{g'(x) \cdot h(x) - g(x) \cdot h'(x)}{h(x)^2}
#    $$
#
# - **Chain Rule:**
#    If $ f(x) = g(h(x)) $, then:
#    $$
#    f'(x) = g'(h(x)) \cdot h'(x)
#    $$
#
# ##### Applications of Derivatives:
# - **Finding Tangent Lines:**
#    The derivative gives the slope of the tangent line at any point on a curve.
#
# - **Optimization:**
#    Derivatives are used to find maxima and minima of functions by setting $ f'(x) = 0 $ and analyzing the critical points.
#
# - **Related Rates:**
#    Derivatives are used in problems involving rates of change of related quantities.
#
# - **Motion:**
#    In physics, the derivative of the position function gives velocity, and the derivative of the velocity function gives acceleration.

# %% [markdown]
# ####excercise 1.20
#
# ##### Calculate the derivative of the function $f(x) = 2x^2$ at $x = 3$ using the numerical approximation method:
#
# #####Given the function:
#
# $$
# f(x) = 2x^2
# $$
#
# #####and using the derivative approximation formula:
#
# $$
# \text{Derivative} = \frac{f(x + h) - f(x)}{h}
# $$
#
# #####where $h$ is a small step size.
#
# #####For this example, use a step size of $h = 0.1$.
#
# #####Do not use any built-in libraries for differentiation

# %%
def derivative_x(f, x, step_size):
    m = (f(x + step_size) - f(x)) / step_size
    return m

def my_function(x):
    return 2*x**2

slope_in_point_3 = derivative_x(my_function, 3, .01)

print(slope_in_point_3)
# Out:
# 12.019999999999698

# %% [markdown]
# ####excercise 1.21
#
# ##### Calculate the derivative of $f(x) = 3x^4$.
#
# ######Given the function:
#
# ######$$ f(x) = 3x^4 $$
#
# #####Use `sympy` to compute the derivative $f'(x)$ and output the result

# %%
x = symbols('x')

f = 3 * x**4

dx_f = diff(f)

print(dx_f)
# Out:
# 12*x**3

# %% [markdown]
# #### excercise 1.22
#
# ##### Using the derivative from the previous exercise, calculate the derivative at the points $x = [1,4,5,7,8]$.

# %%
points = [1,4,5,7,8]


for point in points:
    derivative_at_point = dx_f.subs(x, point)
    print(f'Derviative at x = {point}: {derivative_at_point }')
# Out:
# Derviative at x = 1: 12
# Derviative at x = 4: 768
# Derviative at x = 5: 1500
# Derviative at x = 7: 4116
# Derviative at x = 8: 6144

# %% [markdown]
# ##### Calculate the partial derivatives of the function $f(x, y) = 3x^2 + 2y^5$ with respect to $x$ and $y$. Additionally, plot the 3D graph of the function.

# %%
x, y = symbols('x y')

f = 3*x**2 + 2*y**5

dx_f = diff(f, x)
dy_f = diff(f, y)

print(dx_f)
print(dy_f)
print(plot3d(f))
# Out:
# 6*x
# 10*y**4
# Plot object containing:
# [0]: cartesian surface: 3*x**2 + 2*y**5 for x over (-10.0, 10.0) and y over (-10.0, 10.0)

# %% [markdown]
# - Use of limits to calculate derivatives

# %% [markdown]
# ####excercise 1.23
#
# ##### Using the definition of a derivative, calculate the derivative of the function $f(x) = 2x^3 -1$ at $x = 4$:
#
# #####Use the approximation formula for the derivative:
#
# #####$$
# f'(x) = \lim_{\Delta x \to 0} \frac{f(x + \Delta x) - f(x)}{\Delta x}
# $$
#
# #####Where $\Delta x$ is a small change in $x$.
#
# #####For this example, set $\Delta x = 0.0001$ and calculate the derivative at $x = 4$.

# %% [markdown]
# I way

# %%
def f(x):
    return 2*x**3 - 1

def derivative_limit(f, x, delta_x):
    return (f(x + delta_x) - f(x)) / delta_x

x_value = 4
delta_x = 0.01

derivative_at_4 = derivative_limit(f, x_value, delta_x)
print(derivative_at_4)
# Out:
# 96.24019999999689

# %% [markdown]
# II way

# %%
h, x = symbols('h, x')

f =2* (x+h)**3 - 1

derivative_at_4 = limit((f - (2*x**3 - 1)) / h,h,0)

derivative_at_4 .subs(x,4)
# Out:
# 96

# %% [markdown]
# #### exercise 1.24
#
# ##### Using the chain rule, calculate the derivative of the function $ f(x) = (4x - 1)^3 $
#
# ##### The function is a composition of two functions:
# - The outer function is $ g(u) = u^3 $,
# - The inner function is $ h(x) = 4x -1 $.

# %%
import sympy as sp

x = symbols('x')

f = (4*x - 1)**3
f_prime = diff(f,x)

print(f"The derivative of the function f(x) = (4x + 2)^3 is:", f_prime)
# Out:
# The derivative of the function f(x) = (4x + 2)^3 is: 12*(4*x - 1)**2
